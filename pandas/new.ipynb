# %%
import pandas as pd
import numpy as np
import pdfplumber
df=pd.read_csv("first.csv")            
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15280\14828426.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pdfplumber
#       4 df=pd.read_csv("first.csv")
#       5 df
#
# ModuleNotFoundError: No module named 'pdfplumber'

# %%
df.drop([0],axis=0,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15280\4241589661.py in <module>
# ----> 1 df.drop([0],axis=0,inplace=True)
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
ss=df.iloc[0]
ss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15280\3679940906.py in <module>
# ----> 1 ss=df.iloc[0]
#       2 ss
#
# NameError: name 'df' is not defined

# %%
dd=df[1:]
dd.columns=ss
dd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15280\953041129.py in <module>
# ----> 1 dd=df[1:]
#       2 dd.columns=ss
#       3 dd.head()
#
# NameError: name 'df' is not defined

# %%
dd["Manhole_ID"]="779390-566883"
dd
# Out:
# C:\Users\vigne\AppData\Local\Temp\ipykernel_11140\1671089821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd["Manhole_ID"]="779390-566883"
# 1  Item Name Sequence                                           Question  \
# 2    Manhole      NaN                                                NaN
# 3    Manhole      NaN                                                NaN
# 4    Manhole        1           Is the manhole available for inspection?
# 5    Manhole        2  What is combustible gas percentage?  If gas\rp...
# 6    Manhole        3                               Voltage on the cover
# 7    Manhole        4                                       Manhole type
# ...

# %%
dd.drop([2],axis=0,inplace=True)
dd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11140\1302145014.py in <module>
# ----> 1 dd.drop([2],axis=0,inplace=True)
#       2 dd
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
dd
# Out:
# 1  Item Name Sequence                                           Question  \
# 4    Manhole        1           Is the manhole available for inspection?
# 5    Manhole        2  What is combustible gas percentage?  If gas\rp...
# 6    Manhole        3                               Voltage on the cover
# 7    Manhole        4                                       Manhole type
# 8    Manhole        5                                    Cover condition
# 9    Manhole        6                                         Cover size
# 10   Manhole        7                                         Cover type
# 11   Manhole        8                                    Free of debris?
# 12   Manhole        9                                 Free of water/mud?
# 13   Manhole       10                                  Manhole condition
#
# 1         Primary Answer Secondary Answer Answer Priority     Manhole_ID
# 4                    Yes              NaN            None  779390-566883
# ...

# %%
dd.columns
# Out:
# Index(['Item Name', 'Sequence', 'Question', 'Primary Answer',
#        'Secondary Answer', 'Answer Priority', 'Manhole_ID'],
#       dtype='object', name=1)

# %%
dd=dd[['Manhole_ID','Item Name', 'Sequence', 'Question', 'Primary Answer',
       'Secondary Answer', 'Answer Priority']]

# %%
dd
# Out:
# 1      Manhole_ID Item Name Sequence  \
# 4   779390-566883   Manhole        1
# 5   779390-566883   Manhole        2
# 6   779390-566883   Manhole        3
# 7   779390-566883   Manhole        4
# 8   779390-566883   Manhole        5
# 9   779390-566883   Manhole        6
# 10  779390-566883   Manhole        7
# 11  779390-566883   Manhole        8
# 12  779390-566883   Manhole        9
# 13  779390-566883   Manhole       10
#
# 1                                            Question        Primary Answer  \
# 4            Is the manhole available for inspection?                   Yes
# 5   What is combustible gas percentage?  If gas\rp...                    0%
# 6                                Voltage on the cover                    No
# 7                                        Manhole type              Sidewalk
# 8                                     Cover condition                  Good
# 9                                          Cover size               28 inch
# ...

# %%
dd.to_csv("new.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15280\4225472699.py in <module>
# ----> 1 dd.to_csv("new.csv",index=False)
#
# NameError: name 'dd' is not defined
